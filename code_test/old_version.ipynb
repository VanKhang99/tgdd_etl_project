# %%
# class Product:
#     def __init__(self, product_id, parent_tag, parent_image_link_class):
#         self.parent_tag = parent_tag
#         self.product_id = product_id
        
#         self.find_name()
#         self.find_brand()
#         self.find_original_price()
#         self.find_current_price()
#         self.find_gift()
#         self.find_percent_discounted()
#         self.find_installment_zero_percent()
#         self.find_link()
#         self.find_image_link(parent_image_link_class)
    
#     def find_prices(self, chilg_tag, attribute_name):
#         value_after_handled = check_element_html(self.parent_tag, chilg_tag)
        
#         # Check if not none , assgin transformed value, else assign None
#         if value_after_handled is not None:
#             value_after_handled = int(value_after_handled.text.replace('₫', '').replace('.', ''))
        
#         setattr(self, attribute_name, value_after_handled) 
    
#     def find_name(self):
#         name = self.parent_tag.find_element(By.XPATH, "./a[@class='main-contain ']").get_attribute('data-name')
#         self.name = name

#     def find_brand(self):
#         brand = self.parent_tag.find_element(By.XPATH, "./a[@class='main-contain ']").get_attribute('data-brand')
#         self.brand = brand
    
#     def find_original_price(self):
#         self.find_prices("./a[@class='main-contain ']//div[@class='box-p']/p[@class='price-old black']", 'original_price')

#     def find_current_price(self):
#         self.find_prices("./a[@class='main-contain ']//strong[@class='price']", 'current_price')

#     def find_gift(self):
#         # self.find_prices("./a[@class='main-contain ']//p[@class='item-gift']/b", 'present_value')
#         gift = check_element_html(self.parent_tag, "./a[@class='main-contain ']//p[@class='item-gift']")
        
#         # Check if not none , assgin transformed value, else assign None
#         if gift is not None:
#             gift = gift.text
        
#         self.gift = gift

#     def find_percent_discounted(self):
#         value_after_handled = check_element_html(self.parent_tag, "./a[@class='main-contain ']//div[@class='box-p']/span[@class='percent']")
        
#         # Check if not none , assgin transformed value, else assign None
#         if value_after_handled is not None:
#             value_after_handled = int(re.findall(r'[\d]+', value_after_handled.text)[0])
            
#         self.percent_discounted = value_after_handled

#     def find_installment_zero_percent(self):
#         value_after_handled = check_element_html(self.parent_tag, "./a[@class='main-contain ']/div[@class='item-label']/span[@class='lb-tragop']")   
#         self.installment_zero_percent = 1 if value_after_handled is not None else 0

#     def find_link(self):
#         link = self.parent_tag.find_element(By.XPATH, "./a[@class='main-contain ']").get_attribute('href') 
#         self.link = link

#     def find_image_link(self, parent_class):
#         image_tag = self.parent_tag.find_element(By.XPATH, f"./a[@class='main-contain ']//div[@class='{parent_class}']/img")
#         if image_tag.get_attribute('data-src') is None:
#             image_link = image_tag.get_attribute('src')
#         else:
#             image_link = image_tag.get_attribute('data-src').replace(' ', '%20')

#         self.image_link = image_link

# %%
        # for tag in specification_tags:
        #     specification_values = tag.text.split(':')[1].strip()
            
        #     if 'Màn hình' in tag.text:
        #         self.handle_data_screen(specification_values)
        #     elif 'Card' in tag.text:
        #         self.card_screen = specification_values
        #     elif 'CPU' in tag.text:
        #         self.handle_data_cpu(specification_values)
        #     elif 'Pin' in tag.text:
        #         self.battery = specification_values
        #     elif 'Khối lượng' in tag.text:
        #         self.weight_kg = float(specification_values.replace(' kg', ''))

# %%
# for tag in ram_capacity_tags:
        #     if 'RAM' in tag.text:
        #         self.ram = tranform_int('[\d]+', tag.text, 0)
        #     elif 'SSD' or 'HDD' in tag.text:
        #         self.capacity = tranform_int('[\d]+', tag.text, 0)
